# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-home/DSwCC/blob/main/m5301041.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Sample Section

# %%
print('This is a sample Python cell.')
x = 10
y = 20
print(f'The sum of x and y is {x+y}')
# Out:
# This is a sample Python cell.
# The sum of x and y is 30

# %% [markdown]
# This is another sample markdown cell, demonstrating some **bold** and *italic* text.

# %%
# !pip install pami
