# %% [markdown]
# <a href="https://colab.research.google.com/github/s1300186/DSwCC/blob/main/m5301021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HelloWorld")
# Out:
# HelloWorld

# %%
# !pip install pami

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_944/1430495939.py in <cell line: 0>()
# ----> 1 if torch.cuda.is_available():
#       2     device = torch.device("cuda")
#       3 elif torch.backends.mps.is_available():
#       4     device = torch.device("mps")
#       5 else:
#
# NameError: name 'torch' is not defined
